# %%
# Out:
# Saved CSV to /home/prezaei/mavlogs/log_24_2024-8-21-17-27-44.csv
#   mavpackettype   Type  Length  Name Format                          Columns  \
# 0           FMT  128.0    89.0   FMT  BBnNZ  Type,Length,Name,Format,Columns
# 1           FMT  115.0    76.0  UNIT    QbZ                  TimeUS,Id,Label
# 2           FMT  114.0    44.0  FMTU   QBNN   TimeUS,FmtType,UnitIds,MultIds
# 3           FMT  116.0    20.0  MULT    Qbd                   TimeUS,Id,Mult
# 4           FMT   32.0    35.0  PARM   QNff        TimeUS,Name,Value,Default
#
#    TimeUS  Value  Default  Instance  ...  SRate  Gain  Param  Subsys  ECode  \
# 0     NaN    NaN      NaN       NaN  ...    NaN   NaN    NaN     NaN    NaN
# 1     NaN    NaN      NaN       NaN  ...    NaN   NaN    NaN     NaN    NaN
# 2     NaN    NaN      NaN       NaN  ...    NaN   NaN    NaN     NaN    NaN
# 3     NaN    NaN      NaN       NaN  ...    NaN   NaN    NaN     NaN    NaN
# ...

# %%
# Load the CSV file into a DataFrame
csv_file = "log_24_2024-8-21-17-27-44.csv"  # Replace with your file path
df = pd.read_csv(csv_file)

# Display the first few rows
print(df.head())
# Out:
# /tmp/ipykernel_5492/3286026411.py:3: DtypeWarning: Columns (4,5,249,250,268,270,277,297,298,414) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_file)
#   mavpackettype   Type  Length  Name Format                          Columns  \
# 0           FMT  128.0    89.0   FMT  BBnNZ  Type,Length,Name,Format,Columns
# 1           FMT  115.0    76.0  UNIT    QbZ                  TimeUS,Id,Label
# 2           FMT  114.0    44.0  FMTU   QBNN   TimeUS,FmtType,UnitIds,MultIds
# 3           FMT  116.0    20.0  MULT    Qbd                   TimeUS,Id,Mult
# 4           FMT   32.0    35.0  PARM   QNff        TimeUS,Name,Value,Default
#
#    TimeUS  Value  Default  Instance  ...  SRate  Gain  Param  Subsys  ECode  \
# 0     NaN    NaN      NaN       NaN  ...    NaN   NaN    NaN     NaN    NaN
# 1     NaN    NaN      NaN       NaN  ...    NaN   NaN    NaN     NaN    NaN
# 2     NaN    NaN      NaN       NaN  ...    NaN   NaN    NaN     NaN    NaN
# ...

# %%
# General info about the dataset
df.info()

# Summary statistics
print(df.describe())

# Check for missing values
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103077 entries, 0 to 103076
# Columns: 422 entries, mavpackettype to ADR
# dtypes: float64(410), object(12)
# memory usage: 331.9+ MB
#              Type       Length        TimeUS         Value        Default  \
# count  182.000000  3720.000000  9.935700e+04  1.378000e+03    1242.000000
# mean   116.725275    62.363978  1.253215e+08  2.441118e+06     694.931597
# std     62.053010     8.595495  6.222000e+07  9.040448e+06    8888.157402
# min      0.000000     4.000000  1.924658e+07 -3.000000e+02    -300.000000
# 25%     70.250000    64.000000  5.098292e+07  0.000000e+00       0.000000
# 50%    111.500000    64.000000  1.448753e+08  1.000000e+00       0.000000
# 75%    165.750000    64.000000  1.764828e+08  5.000000e+01       5.000000
# max    254.000000   207.000000  2.078854e+08  3.790588e+07  204800.000000
#
#            Instance           RPM        RawRPM          Volt          Curr  \
# ...

# %%
# Get the unique mavpackettypes
packet_types = df['mavpackettype'].unique()

print("Unique mavpackettypes in the DataFrame:")
print(packet_types)
# Out:
# Unique mavpackettypes in the DataFrame:
# ['FMT' 'PARM' 'ESC' 'IMU' 'GPS' 'GPA' 'POWR' 'MCU' 'BAT' 'MAG' 'BARO'
#  'CTUN' 'ATT' 'RATE' 'XKF4' 'XKF1' 'XKF2' 'XKF3' 'XKF5' 'XKFS' 'XKQ'
#  'XKV1' 'XKV2' 'AHR2' 'POS' 'MOTB' 'RCIN' 'RCI2' 'RSSI' 'RCOU' 'RCO2'
#  'VIBE' 'FMTU' 'CTRL' 'DCM' 'EAHR' 'THRO' 'UNIT' 'MULT' 'MSG' 'VER' 'CMD'
#  'RALY' 'FNCE' 'MODE' 'STAK' 'FILE' 'AUXF' 'MAV' 'DU32' 'TERR' 'DSF'
#  'TSYN' 'XKT' 'UBX2' 'EV' 'ORGN' 'PM' 'SRTL' 'MAVC' 'ARM' 'D32' 'XKY0'
#  'XKY1' 'PSCD' 'PSCN' 'PSCE' 'QUIK' 'ERR' 'XKFM']

# %%
# Create a dictionary to hold DataFrames for each mavpackettype
message_dfs = {}

# Group the DataFrame by 'mavpackettype'
grouped = df.groupby('mavpackettype')

# Iterate over each group
for packet_type, group_df in grouped:
    # Reset the index of the group DataFrame
    group_df = group_df.reset_index(drop=True)
    
    # Add the group DataFrame to the dictionary
    message_dfs[packet_type] = group_df
    
    # Print information about the group
    print(f"DataFrame for '{packet_type}': {group_df.shape[0]} rows, {group_df.shape[1]} columns")
# Out:
# DataFrame for 'AHR2': 1280 rows, 422 columns
# DataFrame for 'ARM': 2 rows, 422 columns
# DataFrame for 'ATT': 1281 rows, 422 columns
# DataFrame for 'AUXF': 15 rows, 422 columns
# DataFrame for 'BARO': 1281 rows, 422 columns
# DataFrame for 'BAT': 1280 rows, 422 columns
# DataFrame for 'CMD': 27 rows, 422 columns
# DataFrame for 'CTRL': 1280 rows, 422 columns
# DataFrame for 'CTUN': 1281 rows, 422 columns
# DataFrame for 'D32': 1 rows, 422 columns
# DataFrame for 'DCM': 1280 rows, 422 columns
# DataFrame for 'DSF': 128 rows, 422 columns
# DataFrame for 'DU32': 127 rows, 422 columns
# DataFrame for 'EAHR': 1280 rows, 422 columns
# DataFrame for 'ERR': 7 rows, 422 columns
# DataFrame for 'ESC': 51215 rows, 422 columns
# DataFrame for 'EV': 11 rows, 422 columns
# DataFrame for 'FILE': 3547 rows, 422 columns
# DataFrame for 'FMT': 173 rows, 422 columns
# DataFrame for 'FMTU': 173 rows, 422 columns
# DataFrame for 'FNCE': 5 rows, 422 columns
# DataFrame for 'GPA': 641 rows, 422 columns
# ...

# %%
# Create an empty DataFrame to hold the combined result
combined_df = pd.DataFrame()

# Iterate over each message type DataFrame
for packet_type, message_df in message_dfs.items():
    # Identify columns where all values are null
    all_null_columns = message_df.columns[message_df.isnull().all()].tolist()
    
    # Drop all-null columns
    message_df_cleaned = message_df.drop(columns=all_null_columns)
    
    # Add a column to identify the source packet type (optional)
    message_df_cleaned['mavpackettype'] = packet_type

    # Merge the cleaned DataFrame into the combined DataFrame
    combined_df = pd.concat([combined_df, message_df_cleaned], axis=0, ignore_index=True)
    
    # Print information about the cleaned DataFrame
    print(f"\n'{packet_type}' cleaned:")
    print(f"Dropped {len(all_null_columns)} all-null columns.")
    print(f"Remaining columns ({message_df_cleaned.shape[1]}): {message_df_cleaned.columns.tolist()}")

# Display the combined DataFrame structure
print("\nCombined DataFrame:")
print(combined_df.info())
print(combined_df.head())
# Out:
# 'AHR2' cleaned:
# Dropped 0 all-null columns.
# Remaining columns (12): ['mavpackettype', 'TimeUS', 'Lat', 'Lng', 'Alt', 'Yaw', 'Roll', 'Pitch', 'Q1', 'Q2', 'Q3', 'Q4']
#
# 'ARM' cleaned:
# Dropped 0 all-null columns.
# Remaining columns (6): ['mavpackettype', 'TimeUS', 'ArmState', 'ArmChecks', 'Forced', 'Method']
#
# 'ATT' cleaned:
# Dropped 0 all-null columns.
# Remaining columns (11): ['mavpackettype', 'TimeUS', 'Yaw', 'DesRoll', 'Roll', 'DesPitch', 'Pitch', 'DesYaw', 'ErrRP', 'ErrYaw', 'AEKF']
#
# 'AUXF' cleaned:
# Dropped 0 all-null columns.
# Remaining columns (6): ['mavpackettype', 'TimeUS', 'function', 'pos', 'source', 'result']
#
# 'BARO' cleaned:
# Dropped 0 all-null columns.
# Remaining columns (11): ['mavpackettype', 'TimeUS', 'Temp', 'I', 'Alt', 'SMS', 'Health', 'Press', 'CRt', 'Offset', 'GndTemp']
#
# 'BAT' cleaned:
# Dropped 0 all-null columns.
# ...

# %%
# Display general information about the DataFrame
print("General Information:")
print(combined_df.info())

# Display basic statistics for numeric columns
print("\nBasic Statistics:")
print(combined_df.describe())

# Count null values for each column
print("\nNull Value Counts:")
null_counts = combined_df.isnull().sum()
print(null_counts)

# Calculate the percentage of missing values for each column
print("\nPercentage of Missing Values:")
missing_percentage = (combined_df.isnull().mean() * 100).sort_values(ascending=False)
print(missing_percentage)

# Display columns with more than 50% missing values
print("\nColumns with >50% Missing Values:")
high_null_columns = missing_percentage[missing_percentage > 50]
print(high_null_columns)

# Display columns with 0% missing values
print("\nColumns with No Missing Values:")
no_null_columns = missing_percentage[missing_percentage == 0]
print(no_null_columns)

# Identify duplicate rows (optional)
duplicate_count = combined_df.duplicated().sum()
print(f"\nNumber of duplicate rows: {duplicate_count}")
# Out:
# General Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103077 entries, 0 to 103076
# Columns: 419 entries, mavpackettype to IVE4
# dtypes: float64(407), object(12)
# memory usage: 329.5+ MB
# None
#
# Basic Statistics:
#              TimeUS          Lat          Lng          Alt          Yaw  \
# count  9.935700e+04  4645.000000  3365.000000  7075.000000  7043.000000
# mean   1.253215e+08    24.651660  -117.716669   118.757027   162.169818
# std    6.222000e+07    15.230263     3.516934   128.886807   123.924443
# min    1.924658e+07     0.000000  -117.821868   -11.164291     0.000000
# 25%    5.098292e+07     0.000000  -117.821779     0.000000     0.000000
# 50%    1.448753e+08    34.059122  -117.821697    12.236477   141.630000
# 75%    1.764828e+08    34.059213  -117.821660   264.029999   293.730000
# max    2.078854e+08    34.059591     0.000000   278.009979   359.900000
#
#               Roll        Pitch           Q1           Q2           Q3  ...  \
# ...

# %%
# Drop columns with only one unique value
constant_columns = [col for col in combined_df.columns if combined_df[col].nunique() == 1]
combined_df = combined_df.drop(columns=constant_columns)

print(f"Columns dropped due to constant values: {constant_columns}")
# Out:
# Columns dropped due to constant values: ['Forced', 'AEKF', 'source', 'result', 'I', 'Health', 'GndTemp', 'Inst', 'H', 'Prm1', 'Prm2', 'Prm3', 'Prm4', 'SAlt', 'Dp', 'Lon', 'Flg', 'MotTemp', 'Count', 'Radius', 'YAcc', 'VV', 'RTCMFU', 'RTCMFD', 'GWk', 'U', 'EG', 'EA', 'AH', 'OfsX', 'OfsY', 'OfsZ', 'MOX', 'MOY', 'MOZ', 'chan', 'rxdp', 'flags', 'ss', 'tf', 'TC', 'SC', 'Fr', 'P3', 'P4', 'X', 'Z', 'WL', 'LiftMax', 'BatVolt', 'ThLimit', 'FailFlags', 'LR', 'NLon', 'NL', 'ErrL', 'IntE', 'ErrC', 'Ex', 'AccFlags', 'OMask', 'C17', 'C18', 'MaxPts', 'Action', 'Spacing', 'Pending', 'Loaded', 'SysID', 'BT', 'BST', 'Maj', 'Min', 'Pat', 'FWT', 'FWS', 'APJ', 'BU', 'IMU', 'C', 'VWN', 'VWE', 'IDX', 'IDY', 'IS', 'IVT', 'RErr', 'SVT', 'FS', 'PI', 'NI', 'FIX', 'FIY', 'AFI', 'RI', 'rng', 'Herr', 'MI', 'BI', 'GI', 'AI', 'IMUMin', 'IMUMax', 'V22', 'V23']
